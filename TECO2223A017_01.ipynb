# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('rotten_tomatoes_top_movies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1610 non-null   int64
#  1   title                     1610 non-null   object
#  2   year                      1610 non-null   int64
#  3   synopsis                  1602 non-null   object
#  4   critic_score              1610 non-null   int64
#  5   people_score              1609 non-null   float64
#  6   consensus                 1593 non-null   object
#  7   total_reviews             1610 non-null   int64
#  8   total_ratings             1610 non-null   object
#  9   type                      1610 non-null   object
#  10  rating                    1139 non-null   object
#  11  genre                     1603 non-null   object
#  12  original_language         1570 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'year', 'synopsis', 'critic_score',
#        'people_score', 'consensus', 'total_reviews', 'total_ratings', 'type',
#        'rating', 'genre', 'original_language', 'director', 'producer',
#        'writer', 'release_date_(theaters)', 'release_date_(streaming)',
#        'box_office_(gross_usa)', 'runtime', 'production_co', 'sound_mix',
#        'aspect_ratio', 'view_the_collection', 'crew', 'link'],
#       dtype='object')

# %%
df
# Out:
#       Unnamed: 0                              title  year  \
# 0              0                      Black Panther  2018
# 1              1                  Avengers: Endgame  2019
# 2              2     Mission: Impossible -- Fallout  2018
# 3              3                 Mad Max: Fury Road  2015
# 4              4  Spider-Man: Into the Spider-Verse  2018
# ...          ...                                ...   ...
# 1605        1605                             Priest  2011
# 1606        1606                     September Dawn  2006
# 1607        1607                   American Outlaws  2001
# 1608        1608                          Jonah Hex  2010
# 1609        1609                      Texas Rangers  2001
#
#                                                synopsis  critic_score  \
# 0     After the death of his father, T'Challa return...            96
# 1     Adrift in space with no food or water, Tony St...            94
# ...

# %%
df1=df.set_index('Unnamed: 0')

# %%
df1
# Out:
#                                         title  year  \
# Unnamed: 0
# 0                               Black Panther  2018
# 1                           Avengers: Endgame  2019
# 2              Mission: Impossible -- Fallout  2018
# 3                          Mad Max: Fury Road  2015
# 4           Spider-Man: Into the Spider-Verse  2018
# ...                                       ...   ...
# 1605                                   Priest  2011
# 1606                           September Dawn  2006
# 1607                         American Outlaws  2001
# 1608                                Jonah Hex  2010
# 1609                            Texas Rangers  2001
#
#                                                      synopsis  critic_score  \
# Unnamed: 0
# 0           After the death of his father, T'Challa return...            96
# 1           Adrift in space with no food or water, Tony St...            94
# 2           Ethan Hunt and the IMF team join forces with C...            97
# ...

# %%
missing_count=df.isnull().sum()

# %%
missing_count
# Out:
# Unnamed: 0                     0
# title                          0
# year                           0
# synopsis                       8
# critic_score                   0
# people_score                   0
# consensus                     17
# total_reviews                  0
# total_ratings                  0
# type                           0
# rating                       471
# genre                          7
# original_language             40
# director                       1
# producer                     120
# writer                       344
# release_date_(theaters)      507
# release_date_(streaming)      15
# box_office_(gross_usa)       508
# runtime                        7
# production_co                123
# sound_mix                    685
# aspect_ratio                 946
# view_the_collection         1432
# crew                           0
# link                           0
# dtype: int64

# %%
df[df['people_score'].isnull()]
# Out:
#       Unnamed: 0      title  year  \
# 1190        1190  Shithouse  2020
#
#                                                synopsis  critic_score  \
# 1190  A lonely college freshman forges a strong conn...            97
#
#       people_score                                          consensus  \
# 1190           NaN  A disarmingly tender look at young adult ennui...
#
#       total_reviews total_ratings     type  ... release_date_(theaters)  \
# 1190             58           50+  Romance  ...    Oct 16, 2020 limited
#
#      release_date_(streaming) box_office_(gross_usa) runtime    production_co  \
# 1190             Oct 16, 2020                 $18.1K  1h 42m  CMR Productions
#
#      sound_mix aspect_ratio view_the_collection  \
# 1190       NaN          NaN                 NaN
#
#                                                    crew  \
# 1190  Cooper Raiff, Dylan Gelula, Amy Landecker, Log...
#
#                                            link
# ...

# %%
df['people_score']
# Out:
# 0       79.0
# 1       90.0
# 2       88.0
# 3       86.0
# 4       93.0
#         ...
# 1605    46.0
# 1606    49.0
# 1607    68.0
# 1608    20.0
# 1609    29.0
# Name: people_score, Length: 1610, dtype: float64

# %%
df['title']
# Out:
# 0                           Black Panther
# 1                       Avengers: Endgame
# 2          Mission: Impossible -- Fallout
# 3                      Mad Max: Fury Road
# 4       Spider-Man: Into the Spider-Verse
#                       ...
# 1605                               Priest
# 1606                       September Dawn
# 1607                     American Outlaws
# 1608                            Jonah Hex
# 1609                        Texas Rangers
# Name: title, Length: 1610, dtype: object

# %%
df['people_score'].mean()
# Out:
# 83.40522063393412

# %%
df[df['people_score'].isnull()]
# Out:
#       Unnamed: 0      title  year  \
# 1190        1190  Shithouse  2020
#
#                                                synopsis  critic_score  \
# 1190  A lonely college freshman forges a strong conn...            97
#
#       people_score                                          consensus  \
# 1190           NaN  A disarmingly tender look at young adult ennui...
#
#       total_reviews total_ratings     type  ... release_date_(theaters)  \
# 1190             58           50+  Romance  ...    Oct 16, 2020 limited
#
#      release_date_(streaming) box_office_(gross_usa) runtime    production_co  \
# 1190             Oct 16, 2020                 $18.1K  1h 42m  CMR Productions
#
#      sound_mix aspect_ratio view_the_collection  \
# 1190       NaN          NaN                 NaN
#
#                                                    crew  \
# 1190  Cooper Raiff, Dylan Gelula, Amy Landecker, Log...
#
#                                            link
# ...

# %%
df['people_score']=df['people_score'].fillna('bfill',axis=0)

# %%
df['people_score'].isnull().sum()
# Out:
# 0

# %%
df[df['consensus'].isnull()]
# Out:
#       Unnamed: 0                                          title  year  \
# 223          223          The Discreet Charm of the Bourgeoisie  1972
# 291          291                        Nostalgia for the Light  2010
# 452          452          The Discreet Charm of the Bourgeoisie  1972
# 570          570                        Nostalgia for the Light  2010
# 577          577                         Ai Weiwei: Never Sorry  2012
# 970          970        Marina Abramovic: The Artist Is Present  2012
# 1250        1250          The Discreet Charm of the Bourgeoisie  1972
# 1305        1305          The Discreet Charm of the Bourgeoisie  1972
# 1331        1331                         Ai Weiwei: Never Sorry  2012
# 1394        1394                               5 Broken Cameras  2011
# 1417        1417                                     Boxing Gym  2010
# 1477        1477              Being Elmo: A Puppeteer's Journey  2011
# ...

# %%
df=df.drop('view_the_collection',axis=1)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# title                         0
# year                          0
# synopsis                      8
# critic_score                  0
# people_score                  0
# consensus                    17
# total_reviews                 0
# total_ratings                 0
# type                          0
# rating                      471
# genre                         7
# original_language            40
# director                      1
# producer                    120
# writer                      344
# release_date_(theaters)     507
# release_date_(streaming)     15
# box_office_(gross_usa)      508
# runtime                       7
# production_co               123
# sound_mix                   685
# aspect_ratio                946
# crew                          0
# link                          0
# dtype: int64

# %%
df=df.drop(1190)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# title                         0
# year                          0
# synopsis                      8
# critic_score                  0
# people_score                  0
# consensus                    17
# total_reviews                 0
# total_ratings                 0
# type                          0
# rating                      471
# genre                         7
# original_language            40
# director                      1
# producer                    120
# writer                      344
# release_date_(theaters)     507
# release_date_(streaming)     15
# box_office_(gross_usa)      508
# runtime                       7
# production_co               123
# sound_mix                   685
# crew                          0
# link                          0
# dtype: int64

# %%
df.sort_values(by='critic_score',ascending=False)
# Out:
#       Unnamed: 0                                              title  year  \
# 543          543  Bright Lights: Starring Carrie Fisher and Debb...  2016
# 105          105                                       Paddington 2  2017
# 1303        1303                                        Man on Wire  2008
# 576          576          Sholem Aleichem: Laughing in the Darkness  2011
# 1301        1301                                       Frankenstein  1931
# ...          ...                                                ...   ...
# 1524        1524                                   The Honeymooners  2005
# 1608        1608                                          Jonah Hex  2010
# 1525        1525                               From Justin to Kelly  2003
# 1468        1468                                  Playing for Keeps  2012
# 1609        1609                                      Texas Rangers  2001
#
#                                                synopsis  critic_score  \
# ...

# %%
df.sort_values(by='people_score',ascending=False)
# Out:
#       Unnamed: 0                           title  year  \
# 610          610                   The Godfather  1972
# 520          520               Stop Making Sense  1984
# 922          922               Stop Making Sense  1984
# 1528        1528  The Good, the Bad and the Ugly  1967
# 1019        1019          The Godfather, Part II  1974
# ...          ...                             ...   ...
# 1520        1520                 The Real Cancun  2003
# 1609        1609                   Texas Rangers  2001
# 1604        1604                  Wild Wild West  1999
# 1608        1608                       Jonah Hex  2010
# 521          521            Knock Down the House  2019
#
#                                                synopsis  critic_score  \
# 610   Widely regarded as one of the greatest films o...            97
# 520   Director Jonathan Demme captures the frantic e...           100
# 922   Director Jonathan Demme captures the frantic e...           100
# ...

# %%
df['people_score'].to_numeric(downcast='float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6278/350662919.py in <module>
# ----> 1 df['people_score'].to_numeric(downcast='float')
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_numeric'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1610 non-null   int64
#  1   title                     1610 non-null   object
#  2   year                      1610 non-null   int64
#  3   synopsis                  1602 non-null   object
#  4   critic_score              1610 non-null   int64
#  5   people_score              1610 non-null   object
#  6   consensus                 1593 non-null   object
#  7   total_reviews             1610 non-null   int64
#  8   total_ratings             1610 non-null   object
#  9   type                      1610 non-null   object
#  10  rating                    1139 non-null   object
#  11  genre                     1603 non-null   object
#  12  original_language         1570 non-null   object
# ...

# %%
df['people_score']=df['people_score'].astype(float)

# %%
df
# Out:
#       Unnamed: 0                              title  year  \
# 0              0                      Black Panther  2018
# 1              1                  Avengers: Endgame  2019
# 2              2     Mission: Impossible -- Fallout  2018
# 3              3                 Mad Max: Fury Road  2015
# 4              4  Spider-Man: Into the Spider-Verse  2018
# ...          ...                                ...   ...
# 1605        1605                             Priest  2011
# 1606        1606                     September Dawn  2006
# 1607        1607                   American Outlaws  2001
# 1608        1608                          Jonah Hex  2010
# 1609        1609                      Texas Rangers  2001
#
#                                                synopsis  critic_score  \
# 0     After the death of his father, T'Challa return...            96
# 1     Adrift in space with no food or water, Tony St...            94
# ...
